# %%
import pandas as pd #data frames
import numpy as np #matematica

base = pd.read_excel('BANCO QUADRIL - dezembro 2021.xlsx')

base.head()
# Out:
# C:\Users\ADM\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#    Atendimento  Ano  hospital sexo  idade  asa  \
# 0      8167520  2016   Analia    F     88    2
# 1      8389501  2016   Analia    F     98    3
# 2      7223144  2016   Analia    F     79    2
# 3      8132451  2016   Analia    F     47    1
# 4      8166002  2016   Analia    M     61    1
#
#    TEMPO (DIAS) ANTES DA CIRURGIA   ELETIVA /URGENCIA    peso AVC prévio  ...  \
# 0                              1.0                   2   49.0        não  ...
# 1                              2.0                   2   72.0        não  ...
# 2                              1.0                   1   79.0        não  ...
# 3                              1.0                   1  100.0        não  ...
# 4                              1.0                   2   85.0        não  ...
#
#   Necessidade de DVA    Dor 24h tempo de uti tempo de internação  pcr  \
# 0                não   ausente           2.0                 4.0  não
# 1                não   ausente          19.0                22.0  não
# 2                não   ausente           1.0                 4.0  não
# 3                não   ausente           3.0                 4.0  não
# 4                não  moderada           3.0                 6.0  não
#
#   reintubação transfusão na uti Complicações PO  DRC  comentários
# 0         não               não         ausente  não           NaN
# 1         não               não             TVP  não           NaN
# 2         não               não         ausente  não           NaN
# 3         não               não         ausente  não           NaN
# 4         não               não         ausente  não           NaN
#
# [5 rows x 39 columns]

# %%
display(base.columns)
display(base.shape)
# Out:
# Index(['Atendimento', 'Ano ', 'hospital', 'sexo', 'idade', 'asa',
#        'TEMPO (DIAS) ANTES DA CIRURGIA ', 'ELETIVA /URGENCIA ', 'peso',
#        'AVC prévio', 'tabagismo', 'Doença cardíaca', 'has', 'dm', 'tecnica',
#        'geral', 'tipo', 'peridural', 'tempo cirúrgico (min)', 'líquidos total',
#        'sangramento', 'qtde sangramento', 'DVA', 'transfusão', 'Transamin',
#        'hipotermia', 'protocolo de hipotermia', 'hipotensão no IO > de 20%?',
#        'destino', 'Necessidade de DVA', 'Dor 24h', 'tempo de uti',
#        'tempo de internação', 'pcr', 'reintubação', 'transfusão na uti',
#        'Complicações PO', 'DRC', 'comentários '],
#       dtype='object')
# (327, 39)

# %%
base.describe()
# Out:
#         Atendimento         Ano        idade         asa  \
# count  3.270000e+02   327.000000  327.000000  327.000000
# mean   1.610200e+07  2019.094801   64.746177    2.119266
# std    4.593456e+06     1.490318   17.409885    0.565763
# min    6.931146e+06  2016.000000   17.000000    1.000000
# 25%    1.269079e+07  2018.000000   53.000000    2.000000
# 50%    1.608110e+07  2019.000000   66.000000    2.000000
# 75%    1.985009e+07  2020.000000   79.000000    2.000000
# max    2.441972e+07  2021.000000   98.000000    4.000000
#
#        TEMPO (DIAS) ANTES DA CIRURGIA   ELETIVA /URGENCIA         peso  \
# count                       326.000000          327.000000  327.000000
# mean                          1.423313            1.183486   76.056575
# std                           1.661864            0.387658   16.683566
# min                           0.000000            1.000000   39.000000
# 25%                           1.000000            1.000000   62.000000
# 50%                           1.000000            1.000000   75.000000
# 75%                           1.000000            1.000000   88.000000
# max                          20.000000            2.000000  127.000000
#
#        tempo cirúrgico (min)  líquidos total  tempo de uti  \
# count             327.000000      327.000000    306.000000
# mean              151.571865     1430.892966      2.490196
# std                60.041092      602.031640      6.831093
# min                50.000000      300.000000      0.000000
# 25%               110.000000     1000.000000      0.000000
# 50%               140.000000     1500.000000      1.000000
# 75%               180.000000     1500.000000      2.000000
# max               480.000000     7500.000000     96.000000
#
#        tempo de internação
# count           323.000000
# mean              5.860681
# std               9.537232
# min               1.000000
# 25%               3.000000
# 50%               4.000000
# 75%               5.000000
# max             117.000000

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 327 entries, 0 to 326
# Data columns (total 39 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Atendimento                      327 non-null    int64
#  1   Ano                              327 non-null    int64
#  2   hospital                         327 non-null    object
#  3   sexo                             327 non-null    object
#  4   idade                            327 non-null    int64
#  5   asa                              327 non-null    int64
#  6   TEMPO (DIAS) ANTES DA CIRURGIA   326 non-null    float64
#  7   ELETIVA /URGENCIA                327 non-null    int64
#  8   peso                             327 non-null    float64
#  9   AVC prévio                       327 non-null    object
#  10  tabagismo                        327 non-null    object
#  11  Doença cardíaca                  327 non-null    object
#  12  has                              327 non-null    object
#  13  dm                               327 non-null    object
#  14  tecnica                          327 non-null    object
#  15  geral                            279 non-null    object
#  16  tipo                             291 non-null    object
#  17  peridural                        6 non-null      object
#  18  tempo cirúrgico (min)            327 non-null    int64
#  19  líquidos total                   327 non-null    int64
#  20  sangramento                      327 non-null    object
#  21  qtde sangramento                 294 non-null    object
#  22  DVA                              327 non-null    object
#  23  transfusão                       327 non-null    object
#  24  Transamin                        327 non-null    object
#  25  hipotermia                       327 non-null    object
#  26  protocolo de hipotermia          324 non-null    object
#  27  hipotensão no IO > de 20%?       327 non-null    object
#  28  destino                          327 non-null    object
#  29  Necessidade de DVA               327 non-null    object
#  30  Dor 24h                          327 non-null    object
#  31  tempo de uti                     306 non-null    float64
#  32  tempo de internação              323 non-null    float64
#  33  pcr                              326 non-null    object
#  34  reintubação                      327 non-null    object
#  35  transfusão na uti                327 non-null    object
#  36  Complicações PO                  327 non-null    object
#  37  DRC                              327 non-null    object
#  38  comentários                      10 non-null     object
# dtypes: float64(4), int64(7), object(28)
# memory usage: 99.8+ KB

# %%
for i in base.columns:
    if base[i].dtype == "object":
        print("===>", i, "<===")
        print(base[i].unique())
# Out:
# ===> hospital <===
# ['Analia' 'Villa' 'Jabaquara' 'Jabaquara ']
# ===> sexo <===
# ['F' 'M']
# ===> AVC prévio <===
# ['não' 'sim']
# ===> tabagismo <===
# ['sim' 'não']
# ===> Doença cardíaca <===
# ['não' 'sim' 'Sim']
# ===> has <===
# ['não' 'sim']
# ===> dm <===
# ['sim' 'não']
# ===> tecnica <===
# ['raqui' 'geralraqui' 'geral' 'geralperi']
# ===> geral <===
# ['não' 'inalatoria' 'venosa' nan]
# ===> tipo <===
# ['bupi hiper' 'hipobarica' nan]
# ===> peridural <===
# [nan 'ropi']
# ===> sangramento <===
# ['não' 'sim']
# ===> qtde sangramento <===
# ['?' 0 300 400 700 500 200 100 900 1000 250 50 800 600 350 '>500 SIC' 150
#  nan 450 1500 2000]
# ===> DVA <===
# ['não' 'sim']
# ===> transfusão <===
# ['não' 'sim']
# ===> Transamin <===
# ['não' 'sim']
# ===> hipotermia <===
# ['sim' 'não' 'temperatura não aferida']
# ===> protocolo de hipotermia <===
# ['não aplicado' 'aplicado' nan]
# ===> hipotensão no IO > de 20%? <===
# ['sim' 'não']
# ===> destino <===
# ['uti' 'rpa']
# ===> Necessidade de DVA <===
# ['não' 'sim']
# ===> Dor 24h <===
# ['ausente ' 'moderada ' 'leve' 'intensa']
# ===> pcr <===
# ['não' 'sim' nan]
# ===> reintubação <===
# ['não' 'sim']
# ===> transfusão na uti <===
# ['não' 'sim']
# ===> Complicações PO <===
# ['ausente' 'TVP' 'dor leve-moderada' 'pcr em aesp - 2 minutos'
#  'choque hipovolemico / transfusao' 'delirium' '1 CH em enfermaria'
#  'hipotensao' 'pcr sem rcp' 'choque septico + IRCagudizada'
#  'RETENÇÃO DE URINA NAS PRIMEIRAS 24HS' 'SEPSE DE FOCO A/E'
#  'TAQUICARDIA NO INTRAOPERATÓRIO' 'SIM' 'sangramento pós operatório'
#  'choque hipovolemico / sangramento / transfusao' 'anemia importante'
#  'aumento de creatinina' 'hipotensao '
#  'taquicardia + dor no 2º dia de pos op '
#  'hipotensao e dor requerendo bomba de PCA'
#  'IRpA + sepse foco pulmonar + TEP' 'IRA, desaturacao ' 'CARDIOPATA - FA'
#  'TEP'
#  'Carcinoma renal de células claras recidivado, metastático para ossos >> obito'
#  'HDB' 'BCP' 'LEUCOPENIA' 'dor' 'não' 'IAM tipo 2' 'retenção urinária'
#  'piora da função renal - tto conservador' 'esperou home care' 'sim']
# ===> DRC <===
# ['não' 'sim']
# ===> comentários  <===
# [nan 'pcte paliativo ' 'Nefropatia crônica' 'paliativa' 'delirium' 'óbito'
#  'delirium hiperativo' 'apresentou episódio de vômito durante internação'
#  'delirium, confusão' 'Raquianestesia dificil. Sucesso após 6 tentativas.'
#  'REINTERNACAO COM DOR INTENSA']

# %%
df = base.copy()

# %% [markdown]
# # PRÉ PROCESSAMENTOS:

# %%
#removendo espaços em branco no inicio e fim das colunas e atributos
df.columns = base.columns.str.strip()

for i in df.columns:
    try:
        df[i] = df[i].apply(lambda x: x.strip())
    except:
        continue

# %%
#df['Doença cardíaca'].unique()
df['Doença cardíaca'] = df['Doença cardíaca'].replace({'Sim':'sim'},regex=True)

#ASSA
df['asa'] = df['asa'].replace({4:3}, regex=True)

#GERALPERI
df.drop(df[df['tecnica'] == 'geralperi'].index, inplace=True)

#LIQUIDO
df['liq'] = (df['líquidos total']/df['peso'])/(df['tempo cirúrgico (min)']/60)

#MUDANDO O NOME DA COLUNA
df.rename(columns={'TEMPO (DIAS) ANTES DA CIRURGIA':'priorday', 'hipotensão no IO > de 20%?':'hipo',
                  'ELETIVA /URGENCIA':'ELETIVA_URGENCIA', 'AVC prévio':'AVC_previo',
                  'Doença cardíaca':'Doenca_cardiaca', 'protocolo de hipotermia':'protocolo_de_hipotermia'}, inplace = True)

# %% [markdown]
# # TESTE 1:

# %%
df_1 = df[['Ano','idade','sexo','asa','ELETIVA_URGENCIA','AVC_previo','tabagismo','Doenca_cardiaca','peso','priorday','dm','has','DRC','tecnica','geral','tipo','DVA','sangramento','Transamin','transfusão','hipotermia','protocolo_de_hipotermia','liq','hipo']]

df_1.to_excel('BASE_TESTE_1.xlsx', index=False)

# %%
df_1 = pd.read_excel('BASE_TESTE_1.xlsx')
df_1.head()
# Out:
#     Ano  idade sexo  asa  ELETIVA_URGENCIA AVC_previo tabagismo  \
# 0  2016     88    F    2                 2        não       sim
# 1  2016     98    F    3                 2        não       não
# 2  2016     79    F    2                 1        não       não
# 3  2016     47    F    1                 1        não       não
# 4  2016     61    M    1                 2        não       não
#
#   Doenca_cardiaca   peso  priorday  ...       geral        tipo  DVA  \
# 0             não   49.0       1.0  ...         não  bupi hiper  não
# 1             não   72.0       2.0  ...  inalatoria  hipobarica  não
# 2             não   79.0       1.0  ...         não  bupi hiper  sim
# 3             não  100.0       1.0  ...         não  bupi hiper  não
# 4             não   85.0       1.0  ...      venosa  bupi hiper  não
#
#   sangramento Transamin transfusão hipotermia protocolo_de_hipotermia  \
# 0         não       não        não        sim            não aplicado
# 1         não       não        não        sim            não aplicado
# 2         não       não        não        não            não aplicado
# 3         não       sim        não        sim                aplicado
# 4         não       não        não        sim            não aplicado
#
#          liq hipo
# 0  11.479592  sim
# 1   7.575758  sim
# 2  10.849910  sim
# 3   2.117647  não
# 4   4.411765  não
#
# [5 rows x 24 columns]

# %%
for i in df_1.columns:
    if df_1[i].dtype == "object":
        for t in df_1[i].unique():
            lista = []
            count = 0
            for o in df_1[i].unique():
                lista.append(count)
                count += 1
        print("base$"+str(i)+" = factor(base$"+str(i)+", levels=c("+str(df_1[i].unique())+"), labels=c("+str(lista)+"))")
# Out:
# base$sexo = factor(base$sexo, levels=c(['F' 'M']), labels=c([0, 1]))
# base$AVC_previo = factor(base$AVC_previo, levels=c(['não' 'sim']), labels=c([0, 1]))
# base$tabagismo = factor(base$tabagismo, levels=c(['sim' 'não']), labels=c([0, 1]))
# base$Doenca_cardiaca = factor(base$Doenca_cardiaca, levels=c(['não' 'sim']), labels=c([0, 1]))
# base$dm = factor(base$dm, levels=c(['sim' 'não']), labels=c([0, 1]))
# base$has = factor(base$has, levels=c(['não' 'sim']), labels=c([0, 1]))
# base$DRC = factor(base$DRC, levels=c(['não' 'sim']), labels=c([0, 1]))
# base$tecnica = factor(base$tecnica, levels=c(['raqui' 'geralraqui' 'geral']), labels=c([0, 1, 2]))
# base$geral = factor(base$geral, levels=c(['não' 'inalatoria' 'venosa' nan]), labels=c([0, 1, 2, 3]))
# base$tipo = factor(base$tipo, levels=c(['bupi hiper' 'hipobarica' nan]), labels=c([0, 1, 2]))
# base$DVA = factor(base$DVA, levels=c(['não' 'sim']), labels=c([0, 1]))
# base$sangramento = factor(base$sangramento, levels=c(['não' 'sim']), labels=c([0, 1]))
# base$Transamin = factor(base$Transamin, levels=c(['não' 'sim']), labels=c([0, 1]))
# base$transfusão = factor(base$transfusão, levels=c(['não' 'sim']), labels=c([0, 1]))
# base$hipotermia = factor(base$hipotermia, levels=c(['sim' 'não' 'temperatura não aferida']), labels=c([0, 1, 2]))
# base$protocolo_de_hipotermia = factor(base$protocolo_de_hipotermia, levels=c(['não aplicado' 'aplicado' nan]), labels=c([0, 1, 2]))
# base$hipo = factor(base$hipo, levels=c(['sim' 'não']), labels=c([0, 1]))

# %% [markdown]
# ### HIPOTENSÃO:

# %%
base$sexo = factor(base$sexo, levels=c('F', 'M'), labels=c(0, 1))
base$AVC_previo = factor(base$AVC_previo, levels=c('não', 'sim'), labels=c(0, 1))
base$tabagismo = factor(base$tabagismo, levels=c('sim', 'não'), labels=c(0, 1))
base$Doenca_cardiaca = factor(base$Doenca_cardiaca, levels=c('não', 'sim'), labels=c(0, 1))
base$dm = factor(base$dm, levels=c('sim', 'não'), labels=c(0, 1))
base$has = factor(base$has, levels=c('não', 'sim'), labels=c(0, 1))
base$DRC = factor(base$DRC, levels=c('não', 'sim'), labels=c(0, 1))
base$tecnica = factor(base$tecnica, levels=c('raqui', 'geralraqui', 'geral'), labels=c(0, 1, 2))
base$geral = factor(base$geral, levels=c('não', 'inalatoria', 'venosa' nan), labels=c(0, 1, 2, 3))
base$tipo = factor(base$tipo, levels=c('bupi hiper', 'hipobarica' nan), labels=c([0, 1, 2]))
base$DVA = factor(base$DVA, levels=c('não', 'sim'), labels=c(0, 1))
base$sangramento = factor(base$sangramento, levels=c('não', 'sim'), labels=c(0, 1))
base$Transamin = factor(base$Transamin, levels=c('não', 'sim'), labels=c(0, 1))
base$transfusão = factor(base$transfusão, levels=c('não', 'sim'), labels=c(0, 1))
base$hipotermia = factor(base$hipotermia, levels=c('sim', 'não' 'temperatura não aferida'), labels=c(0, 1, 2))
base$protocolo_de_hipotermia = factor(base$protocolo_de_hipotermia, levels=c('não aplicado', 'aplicado' nan), labels=c(0, 1, 2))
base$hipo = factor(base$hipo, levels=c('sim', 'não'), labels=c(0, 1))
# Out:
#   File "C:\Users\ADM\AppData\Local\Temp/ipykernel_4792/1821004001.py", line 1
#     base$sexo = factor(base$sexo, levels=c('F','M'), labels=c(0, 1))
#         ^
# SyntaxError: invalid syntax
